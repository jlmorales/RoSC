# %%
import pandas as pd
import plotly.graph_objs as go

def readAndClean(filepath, col):
    #filepath = filepath
    data = pd.read_excel(filepath)
    df = pd.DataFrame(data)
    data = df.dropna(subset=[col])
    data = data[:-1]
    dataframe = data
    dataframe = dataframe.dropna(subset=[col])
    return dataframe

def processData(dataframe, col, day):
    dataframe[col] = pd.to_datetime(dataframe[col])
    dataframe['by_hour'] = dataframe[col].dt.floor('h')
    dataframe['by_day'] = dataframe[col].dt.floor('d')
    newdf = dataframe.loc[dataframe['by_day'] == day]
    return newdf
filepath1 = "C4G Agent Activity Detail.xlsx"
dataframe = readAndClean(filepath1,'Activity Time')
df = processData(dataframe, 'Activity Time', '2019-02-02')
counting = df.groupby(['by_hour', 'Activity Detail']).size()
counting

# counting['Activity Detail'].get_group('AVAILABLE')
# groups = dict(list(counting))
# groups
# hours = set(df['by_hour'].T)
# hours = list(hours)

# activity = set(df['Activity Detail'].T)
# activity = 

# hello = counting.apply(lambda x: x[x['Activity Detail']=='AVAILABLE'])
# hello

#newdf = pd.DataFrame(df['by_hour'], df['Agent Name'], df['Activity Detail'])
#newdf
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#     973             try:
# --> 974                 return libindex.get_value_at(s, k)
#     975             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_at()
#
# pandas/_libs/src\util.pxd in util.get_value_at()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-7722c0e7fc04> in <module>
#      22 df = processData(dataframe, 'Activity Time', '2019-02-02')
#      23 counting = df.groupby(['by_hour', 'Activity Detail']).size()
# ---> 24 counting['Activity Detail'].get_group('AVAILABLE')
#      25 # groups = dict(list(counting))
#      26 # groups
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# --> 767             result = self.index.get_value(self, key)
#     768
#     769             if not is_scalar(result):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#     980                     raise InvalidIndexError(key)
#     981                 else:
# --> 982                     raise e1
#     983             except Exception:  # pragma: no cover
#     984                 raise e1
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_value(self, series, key)
#     964
#     965         try:
# --> 966             return self._engine.get_value(s, k)
#     967         except KeyError as e1:
#     968             try:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: 'Activity Detail'

# %%
pd.pivot_table(df, index = ['by_hour', 'Agent Name'], values = ['Activity Detail'], aggfunc= [len])
# Out:
#                                                            len
#                                                Activity Detail
# by_hour             Agent Name
# 2019-02-02 00:00:00 CrisisCenterR302, Response               7
# 2019-02-02 01:00:00 CrisisCenterR302, Response               8
# 2019-02-02 02:00:00 CrisisCenterR302, Response               1
# 2019-02-02 03:00:00 CrisisCenterR301, Response               7
# 2019-02-02 04:00:00 CrisisCenterR301, Response              13
# 2019-02-02 05:00:00 CrisisCenterR301, Response               1
# 2019-02-02 06:00:00 CrisisCenterR301, Response               7
# 2019-02-02 07:00:00 CrisisCenterR301, Response              12
# 2019-02-02 09:00:00 CrisisCenterP101, Response               2
#                     CrisisCenterP103, Response               3
# 2019-02-02 10:00:00 CrisisCenterP101, Response              22
#                     CrisisCenterP102, Response               9
#                     CrisisCenterP103, Response               9
#                     CrisisCenterP105, Response              17
# 2019-02-02 11:00:00 CrisisCenterP101, Response              15
#                     CrisisCenterP102, Response               5
#                     CrisisCenterP103, Response              12
#                     CrisisCenterP105, Response              17
# 2019-02-02 12:00:00 CrisisCenterP101, Response              13
#                     CrisisCenterP102, Response              12
#                     CrisisCenterP103, Response               5
#                     CrisisCenterP105, Response              11
# 2019-02-02 13:00:00 CrisisCenterP101, Response               3
#                     CrisisCenterP103, Response               1
#                     CrisisCenterP105, Response               9
# 2019-02-02 14:00:00 CrisisCenterP101, Response               1
#                     CrisisCenterP103, Response               4
#                     CrisisCenterP105, Response               5
# 2019-02-02 15:00:00 CrisisCenterP103, Response              19
#                     CrisisCenterP105, Response               4
# 2019-02-02 16:00:00 CrisisCenterP102, Response               2
#                     CrisisCenterP103, Response              31
#                     CrisisCenterP104, Response               3
#                     CrisisCenterP105, Response              12
# 2019-02-02 17:00:00 CrisisCenterP102, Response              14
#                     CrisisCenterP103, Response               2
#                     CrisisCenterP104, Response              15
# 2019-02-02 18:00:00 CrisisCenterP102, Response              31
#                     CrisisCenterP103, Response              40
#                     CrisisCenterP104, Response              14
# 2019-02-02 19:00:00 CrisisCenterP102, Response               5
#                     CrisisCenterP104, Response              13
# 2019-02-02 20:00:00 CrisisCenterP102, Response              25
#                     CrisisCenterP103, Response               2
#                     CrisisCenterP104, Response              16
# 2019-02-02 21:00:00 CrisisCenterP102, Response              14
#                     CrisisCenterP103, Response               3
#                     CrisisCenterP104, Response               4
#                     CrisisCenterR301, Response               2
# 2019-02-02 22:00:00 CrisisCenterP101, Response               1
#                     CrisisCenterP102, Response               3
#                     CrisisCenterP103, Response               8
#                     CrisisCenterP104, Response               5
#                     CrisisCenterR301, Response              18
# 2019-02-02 23:00:00 CrisisCenterR301, Response              12
#                     CrisisCenterR303, Response               1
#                     CrisisCenterR305, Response               1

# %%
df
# Out:
#                       Agent Name       Activity Time Activity Type  \
# 492   CrisisCenterR302, Response 2019-02-02 00:05:22          Call
# 493   CrisisCenterR302, Response 2019-02-02 00:05:22         State
# 494   CrisisCenterR302, Response 2019-02-02 00:06:22         State
# 495   CrisisCenterR302, Response 2019-02-02 00:32:02          Call
# 496   CrisisCenterR302, Response 2019-02-02 00:33:05          Call
# 497   CrisisCenterR302, Response 2019-02-02 00:33:05         State
# 498   CrisisCenterR302, Response 2019-02-02 00:34:05         State
# 499   CrisisCenterR302, Response 2019-02-02 01:08:49          Call
# 500   CrisisCenterR302, Response 2019-02-02 01:09:03          Call
# 501   CrisisCenterR302, Response 2019-02-02 01:09:03         State
# 502   CrisisCenterR302, Response 2019-02-02 01:09:07          Call
# 503   CrisisCenterR302, Response 2019-02-02 01:09:07         State
# 504   CrisisCenterR302, Response 2019-02-02 01:09:23          Call
# 505   CrisisCenterR302, Response 2019-02-02 01:09:23         State
# 506   CrisisCenterR302, Response 2019-02-02 01:10:23         State
# 507   CrisisCenterR302, Response 2019-02-02 02:59:59         State
# 508   CrisisCenterR301, Response 2019-02-02 03:04:23         State
#
#      Activity Detail     Call Type  Callers/Called Number Number Called  \
# 492    Call Released   Inbound ACD           6.316472e+09    6317517500
# 493          WRAP-UP           NaN           0.000000e+00           NaN
# 494        AVAILABLE           NaN           0.000000e+00           NaN
# 495           Placed  Outbound ACD           8.452537e+09           NaN
# 496    Call Released  Outbound ACD           8.452537e+09           NaN
# 497          WRAP-UP           NaN           0.000000e+00           NaN
# 498        AVAILABLE           NaN           0.000000e+00           NaN
# 499         Answered   Inbound ACD           6.316647e+09    6317517500
# 500    Call Released   Inbound ACD           6.316647e+09    6317517500
# 501          WRAP-UP           NaN           0.000000e+00           NaN
# 502         Answered   Inbound ACD           6.316647e+09    6317517500
# 503        AVAILABLE           NaN           0.000000e+00           NaN
# 504    Call Released   Inbound ACD           6.316647e+09    6317517500
# 505          WRAP-UP           NaN           0.000000e+00           NaN
# 506        AVAILABLE           NaN           0.000000e+00           NaN
# 507         SIGN-OUT           NaN           0.000000e+00           NaN
# 508          SIGN-IN           NaN           0.000000e+00           NaN
# 509        AVAILABLE           NaN           0.000000e+00           NaN
# 510           Placed  Outbound ACD           6.317595e+09           NaN
# 511    Call Released  Outbound ACD           6.317595e+09           NaN
# 512          WRAP-UP           NaN           0.000000e+00           NaN
# 513        AVAILABLE           NaN           0.000000e+00           NaN
# 514         Answered   Inbound ACD                    NaN    6317517500
# 515    Call Released   Inbound ACD                    NaN    6317517500
# 516          WRAP-UP           NaN           0.000000e+00           NaN
# 517        AVAILABLE           NaN           0.000000e+00           NaN
# 518          SIGN-IN           NaN           0.000000e+00           NaN
# 519        AVAILABLE           NaN           0.000000e+00           NaN
# 520           Placed  Outbound ACD           6.317595e+09           NaN
# 521    Call Released  Outbound ACD           6.317595e+09           NaN
# ...              ...           ...                    ...           ...
# 1013   Call Released      Outbound           7.842700e+04           NaN
# 1014     UNAVAILABLE           NaN           0.000000e+00           NaN
# 1015          Placed  Outbound ACD           6.316507e+09           NaN
# 1016       Call Held  Outbound ACD           6.316507e+09           NaN
# 1017   Call Released  Outbound ACD           6.316507e+09           NaN
# 1018       AVAILABLE           NaN           0.000000e+00           NaN
# 1019        Answered   Inbound ACD           1.718255e+10    6317517500
# 1020   Call Released      Outbound           1.631342e+10           NaN
# 1021   Call Released   Inbound ACD           1.718255e+10    6317517500
# 1022         WRAP-UP           NaN           0.000000e+00           NaN
# 1023       AVAILABLE           NaN           0.000000e+00           NaN
# 1024        Answered   Inbound ACD           6.316770e+09    6317517500
# 1025        SIGN-OUT           NaN           0.000000e+00           NaN
# 1026        SIGN-OUT           NaN           0.000000e+00           NaN
# 1027       Call Held   Inbound ACD           6.316770e+09    6317517500
# 1028  Call Retrieved   Inbound ACD           6.316770e+09    6317517500
# 1029   Call Released   Inbound ACD           6.316770e+09    6317517500
# 1030         WRAP-UP           NaN           0.000000e+00           NaN
# 1031       AVAILABLE           NaN           0.000000e+00           NaN
# 1032   Call Released   Inbound ACD           6.316770e+09    6317517500
# 1033   Call Released   Inbound ACD           6.316770e+09    6317517500
# 1034  UNAVAILABLE 99           NaN           0.000000e+00           NaN
# 1035       AVAILABLE           NaN           0.000000e+00           NaN
# 1036   Call Released   Inbound ACD           9.318090e+09    6317517500
# 1037   Call Released   Inbound ACD                    NaN    6317517500
# 1038   Call Released   Inbound ACD                    NaN    6317517500
# 1039  UNAVAILABLE 99           NaN           0.000000e+00           NaN
# 1040       AVAILABLE           NaN           0.000000e+00           NaN
# 1041       AVAILABLE           NaN           0.000000e+00           NaN
# 1042          Placed  Outbound ACD           6.316647e+09           NaN
#
#      Transfer Number Transfer Location  Unnamed: 9             by_hour  \
# 492              NaN                NaN        NaN 2019-02-02 00:00:00
# 493              NaN                NaN        NaN 2019-02-02 00:00:00
# 494              NaN                NaN        NaN 2019-02-02 00:00:00
# 495              NaN                NaN        NaN 2019-02-02 00:00:00
# 496              NaN                NaN        NaN 2019-02-02 00:00:00
# 497              NaN                NaN        NaN 2019-02-02 00:00:00
# 498              NaN                NaN        NaN 2019-02-02 00:00:00
# 499              NaN                NaN        NaN 2019-02-02 01:00:00
# 500              NaN                NaN        NaN 2019-02-02 01:00:00
# 501              NaN                NaN        NaN 2019-02-02 01:00:00
# 502              NaN                NaN        NaN 2019-02-02 01:00:00
# 503              NaN                NaN        NaN 2019-02-02 01:00:00
# 504              NaN                NaN        NaN 2019-02-02 01:00:00
# 505              NaN                NaN        NaN 2019-02-02 01:00:00
# 506              NaN                NaN        NaN 2019-02-02 01:00:00
# 507              NaN                NaN        NaN 2019-02-02 02:00:00
# 508              NaN                NaN        NaN 2019-02-02 03:00:00
# 509              NaN                NaN        NaN 2019-02-02 03:00:00
# 510              NaN                NaN        NaN 2019-02-02 03:00:00
# 511              NaN                NaN        NaN 2019-02-02 03:00:00
# 512              NaN                NaN        NaN 2019-02-02 03:00:00
# 513              NaN                NaN        NaN 2019-02-02 03:00:00
# 514              NaN                NaN        NaN 2019-02-02 03:00:00
# 515              NaN                NaN        NaN 2019-02-02 04:00:00
# 516              NaN                NaN        NaN 2019-02-02 04:00:00
# 517              NaN                NaN        NaN 2019-02-02 04:00:00
# 518              NaN                NaN        NaN 2019-02-02 04:00:00
# 519              NaN                NaN        NaN 2019-02-02 04:00:00
# 520              NaN                NaN        NaN 2019-02-02 04:00:00
# 521              NaN                NaN        NaN 2019-02-02 04:00:00
# ...              ...                ...        ...                 ...
# 1013             NaN                NaN        NaN 2019-02-02 22:00:00
# 1014             NaN                NaN        NaN 2019-02-02 22:00:00
# 1015             NaN                NaN        NaN 2019-02-02 22:00:00
# 1016             NaN                NaN        NaN 2019-02-02 22:00:00
# 1017             NaN                NaN        NaN 2019-02-02 22:00:00
# 1018             NaN                NaN        NaN 2019-02-02 22:00:00
