# %%
import pandas as pd

filepath = "C4G Agent Activity Detail.csv"
data = pd.read_csv(filepath)
df = pd.DataFrame(data)

# %%
df
# Out:
#                                               Agent Name  \
# 0                             CrisisCenterR301, Response
# 1                             CrisisCenterR301, Response
# 2                             CrisisCenterR301, Response
# 3                             CrisisCenterR301, Response
# 4                             CrisisCenterR301, Response
# 5                             CrisisCenterR301, Response
# 6                             CrisisCenterR301, Response
# 7                             CrisisCenterR301, Response
# 8                             CrisisCenterR301, Response
# 9                             CrisisCenterR301, Response
# 10                            CrisisCenterR301, Response
# 11                            CrisisCenterR301, Response
# 12                            CrisisCenterR301, Response
# 13                            CrisisCenterR301, Response
# 14                            CrisisCenterR301, Response
# 15                            CrisisCenterR301, Response
# 16                            CrisisCenterR301, Response
# 17                            CrisisCenterR301, Response
# 18                            CrisisCenterR301, Response
# 19                            CrisisCenterR301, Response
# 20                            CrisisCenterR301, Response
# 21                            CrisisCenterR301, Response
# 22                            CrisisCenterR301, Response
# 23                            CrisisCenterR301, Response
# 24                            CrisisCenterR301, Response
# 25                            CrisisCenterR301, Response
# 26                            CrisisCenterR301, Response
# 27                            CrisisCenterR301, Response
# 28                            CrisisCenterR301, Response
# 29                            CrisisCenterR301, Response
# ...                                                  ...
# 13736                         CrisisCenterP101, Response
# 13737                         CrisisCenterP101, Response
# 13738                         CrisisCenterP101, Response
# 13739                         CrisisCenterP101, Response
# 13740                         CrisisCenterP101, Response
# 13741                         CrisisCenterP101, Response
# 13742                         CrisisCenterP101, Response
# 13743                         CrisisCenterP101, Response
# 13744                         CrisisCenterP101, Response
# 13745                         CrisisCenterP101, Response
# 13746                         CrisisCenterP101, Response
# 13747                         CrisisCenterP101, Response
# 13748                         CrisisCenterP101, Response
# 13749                         CrisisCenterP101, Response
# 13750                         CrisisCenterP101, Response
# 13751                         CrisisCenterP101, Response
# 13752                         CrisisCenterP101, Response
# 13753                         CrisisCenterP101, Response
# 13754                         CrisisCenterP101, Response
# 13755                         CrisisCenterR301, Response
# 13756                         CrisisCenterR301, Response
# 13757                         CrisisCenterR301, Response
# 13758                         CrisisCenterR301, Response
# 13759                         CrisisCenterR301, Response
# 13760                         CrisisCenterR301, Response
# 13761                         CrisisCenterR301, Response
# 13762                                                NaN
# 13763                                                NaN
# 13764                                        Page 1 of 1
# 13765  Proprietary and Confidential, do not copy, dup...
#
#                  Activity Time Activity Type Activity Detail     Call Type  \
# 0      02/01/2019, 12:37:06 AM          Call        Answered   Inbound ACD
# 1      02/01/2019, 12:42:47 AM          Call   Call Released   Inbound ACD
# 2      02/01/2019, 12:05:47 AM          Call          Placed  Outbound ACD
# 3      02/01/2019, 12:06:50 AM          Call   Call Released  Outbound ACD
# 4      02/01/2019, 12:05:28 AM          Call   Call Released   Inbound ACD
# 5      02/01/2019, 12:07:03 AM          Call          Placed  Outbound ACD
# 6      02/01/2019, 12:06:50 AM         State         WRAP-UP           NaN
# 7      02/01/2019, 12:07:12 AM         State       AVAILABLE           NaN
# 8      02/01/2019, 12:12:32 AM         State         WRAP-UP           NaN
# 9      02/01/2019, 12:12:40 AM         State  UNAVAILABLE 99           NaN
# 10     02/01/2019, 12:32:36 AM         State       AVAILABLE           NaN
# 11     02/01/2019, 12:42:47 AM         State         WRAP-UP           NaN
# 12     02/01/2019, 12:12:32 AM          Call   Call Released  Outbound ACD
# 13     02/01/2019, 12:19:42 AM          Call          Placed  Outbound ACD
# 14     02/01/2019, 12:20:51 AM          Call   Call Released  Outbound ACD
# 15     02/01/2019, 12:43:47 AM         State       AVAILABLE           NaN
# 16     02/01/2019, 01:38:11 AM          Call   Call Released   Inbound ACD
# 17     02/01/2019, 01:38:15 AM          Call        Answered   Inbound ACD
# 18     02/01/2019, 01:51:53 AM          Call   Call Released   Inbound ACD
# 19     02/01/2019, 01:51:53 AM         State         WRAP-UP           NaN
# 20     02/01/2019, 01:52:21 AM          Call        Answered   Inbound ACD
# 21     02/01/2019, 01:52:21 AM         State       AVAILABLE           NaN
# 22     02/01/2019, 02:15:39 AM          Call   Call Released   Inbound ACD
# 23     02/01/2019, 02:15:39 AM         State         WRAP-UP           NaN
# 24     02/01/2019, 02:16:39 AM         State       AVAILABLE           NaN
# 25     02/01/2019, 02:57:50 AM          Call          Placed  Outbound ACD
# 26     02/01/2019, 02:58:28 AM          Call   Call Released  Outbound ACD
# 27     02/01/2019, 02:58:28 AM         State         WRAP-UP           NaN
# 28     02/01/2019, 02:59:20 AM         State     UNAVAILABLE           NaN
# 29     02/01/2019, 02:59:27 AM         State     UNAVAILABLE           NaN
# ...                        ...           ...             ...           ...
# 13736  02/27/2019, 08:57:01 PM          Call          Placed      Outbound
# 13737  02/27/2019, 08:57:02 PM          Call   Call Released      Outbound
# 13738  02/27/2019, 08:58:10 PM         State       AVAILABLE           NaN
# 13739  02/27/2019, 09:17:01 PM         State  UNAVAILABLE 01           NaN
# 13740  02/27/2019, 09:19:25 PM         State       AVAILABLE           NaN
# 13741  02/27/2019, 09:19:35 PM          Call          Placed      Outbound
# 13742  02/27/2019, 09:19:41 PM          Call   Call Released      Outbound
# 13743  02/27/2019, 09:20:00 PM          Call          Placed      Outbound
# 13744  02/27/2019, 09:37:59 PM          Call   Call Released      Outbound
# 13745  02/27/2019, 09:38:01 PM         State         WRAP-UP           NaN
# 13746  02/27/2019, 09:38:18 PM         State       AVAILABLE           NaN
# 13747  02/27/2019, 09:38:24 PM          Call          Placed      Outbound
# 13748  02/27/2019, 09:39:25 PM          Call   Call Released      Outbound
# 13749  02/27/2019, 09:39:27 PM         State         WRAP-UP           NaN
# 13750  02/27/2019, 09:41:20 PM         State       AVAILABLE           NaN
# 13751  02/27/2019, 09:41:42 PM          Call        Answered   Inbound ACD
# 13752  02/27/2019, 09:41:45 PM          Call   Call Released   Inbound ACD
# 13753  02/27/2019, 09:41:45 PM         State         WRAP-UP           NaN
# 13754  02/27/2019, 09:42:09 PM         State        SIGN-OUT           NaN
# 13755  02/27/2019, 11:37:29 PM         State         SIGN-IN           NaN
# 13756  02/27/2019, 11:37:45 PM         State       AVAILABLE           NaN
# 13757  02/27/2019, 11:38:24 PM          Call          Placed  Outbound ACD
# 13758  02/27/2019, 11:40:06 PM          Call   Call Released  Outbound ACD
# 13759  02/27/2019, 11:40:06 PM         State         WRAP-UP           NaN
# 13760  02/27/2019, 11:40:29 PM          Call          Placed  Outbound ACD
# 13761  02/27/2019, 11:40:40 PM         State       AVAILABLE           NaN
# 13762                        a             a               a             a
# 13763                      NaN           NaN             NaN           NaN
# 13764                      NaN           NaN             NaN           NaN
# 13765                      NaN           NaN             NaN           NaN
#
#       Callers/Called Number Number Called Transfer Number Transfer Location   \
# 0                5162440030    6316893148             NaN                NaN
# 1                5162440030           NaN             NaN                NaN
# 2                5419295921           NaN             NaN                NaN
# 3                5419295921           NaN             NaN                NaN
# 4                6312830734           NaN             NaN                NaN
# 5                6312830734           NaN             NaN                NaN
# 6                         0           NaN             NaN                NaN
# 7                         0           NaN             NaN                NaN
# 8                         0           NaN             NaN                NaN
# 9                         0           NaN             NaN                NaN
# 10                        0           NaN             NaN                NaN
# 11                        0           NaN             NaN                NaN
# 12               8452537041    6317517500             NaN                NaN
# 13               8452537041    6317517500             NaN                NaN
# 14               8452537042           NaN             NaN                NaN
# 15                        0           NaN             NaN                NaN
# 16               6315966566    6317517500             NaN                NaN
# 17               6315966566    6317517500             NaN                NaN
# 18               6315966566    6317517500             NaN                NaN
# 19                        0           NaN             NaN                NaN
# 20                        0    6317517500             NaN                NaN
# 21                        0           NaN             NaN                NaN
# 22                        0    6317517500             NaN                NaN
# 23                        0           NaN             NaN                NaN
# 24                        0           NaN             NaN                NaN
# 25               6317595102           NaN             NaN                NaN
# 26               6317595102           NaN             NaN                NaN
# 27                        0           NaN             NaN                NaN
# 28                        0           NaN             NaN                NaN
# 29                        0           NaN             NaN                NaN
# ...                     ...           ...             ...                ...
# 13736            6313404587           NaN             NaN                NaN
# 13737            6313404587           NaN             NaN                NaN
# 13738                     0           NaN             NaN                NaN
# 13739                     0           NaN             NaN                NaN
# 13740                     0           NaN             NaN                NaN
# 13741            6317988864           NaN             NaN                NaN
# 13742            6317988864           NaN             NaN                NaN
# 13743            6318008864           NaN             NaN                NaN
# 13744            6318008864           NaN             NaN                NaN
# 13745                     0           NaN             NaN                NaN
# 13746                     0           NaN             NaN                NaN
# 13747            5162808343           NaN             NaN                NaN
# 13748            5162808343           NaN             NaN                NaN
# 13749                     0           NaN             NaN                NaN
# 13750                     0           NaN             NaN                NaN
# 13751            6316894169    6317517402             NaN                NaN
# 13752            6316894169    6317517402             NaN                NaN
# 13753                     0           NaN             NaN                NaN
# 13754                     0           NaN             NaN                NaN
# 13755                     0           NaN             NaN                NaN
# 13756                     0           NaN             NaN                NaN
# 13757            6317595102           NaN             NaN                NaN
# 13758            6317595102           NaN             NaN                NaN
# 13759                     0           NaN             NaN                NaN
# 13760            8453893220           NaN             NaN                NaN
# 13761                     0           NaN             NaN                NaN
# 13762               #VALUE!             a               a                  a
# 13763                   NaN           NaN             NaN                NaN
# 13764                   NaN           NaN             NaN                NaN
# 13765                   NaN           NaN             NaN                NaN
#
#       Unnamed: 9
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ...          ...
# 13736        NaN
# 13737        NaN
# 13738        NaN
# 13739        NaN
# 13740        NaN
# 13741        NaN
# 13742        NaN
# 13743        NaN
# 13744        NaN
# 13745        NaN
# 13746        NaN
# 13747        NaN
# 13748        NaN
# 13749        NaN
# 13750        NaN
# 13751        NaN
# 13752        NaN
# 13753        NaN
# 13754        NaN
# 13755        NaN
# 13756        NaN
# 13757        NaN
# 13758        NaN
# 13759        NaN
# 13760        NaN
# 13761        NaN
# 13762          a
# 13763        NaN
# 13764        NaN
# 13765        NaN
#
# [13766 rows x 10 columns]

# %%
s = pd.to_datetime(df['Activity Time'])
print(s)
# daydf = s.groupby(s.dt.floor('d')).size().reset_index(name='count')
# daydf
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-841f743a2c15> in <module>
# ----> 1 s = pd.to_datetime(df['Activity Time'])
#       2 daydf = s.groupby(s.dt.floor('d')).size().reset_index(name='count')
#       3 daydf
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     449         else:
#     450             from pandas import Series
# --> 451             values = _convert_listlike(arg._values, True, format)
#     452             result = Series(values, index=arg.index, name=arg.name)
#     453     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     379             except (ValueError, TypeError):
# --> 380                 raise e
#     381
#     382     if arg is None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     366                     dayfirst=dayfirst,
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#     370
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ValueError: Given date string not likely a datetime.

# %%
# s = pd.to_datetime(df['Activity Time'])
# daydf = s.groupby(s.dt.floor('d')).size().reset_index(name='count')
# from matplotlib import pyplot
# pyplot.hist(daydf['count'])

# s = pd.to_datetime(df['Call Start Time'])
# daydf = s.groupby(s.dt.floor('d')).size().reset_index(name='count')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     376             try:
# --> 377                 values, tz = conversion.datetime_to_datetime64(arg)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-3bb2b984ec6e> in <module>
# ----> 1 s = pd.to_datetime(df['Activity Time'])
#       2 daydf = s.groupby(s.dt.floor('d')).size().reset_index(name='count')
#       3 from matplotlib import pyplot
#       4 pyplot.hist(daydf['count'])
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in to_datetime(arg, errors, dayfirst, yearfirst, utc, box, format, exact, unit, infer_datetime_format, origin, cache)
#     449         else:
#     450             from pandas import Series
# --> 451             values = _convert_listlike(arg._values, True, format)
#     452             result = Series(values, index=arg.index, name=arg.name)
#     453     elif isinstance(arg, (ABCDataFrame, MutableMapping)):
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     378                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#     379             except (ValueError, TypeError):
# --> 380                 raise e
#     381
#     382     if arg is None:
#
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     366                     dayfirst=dayfirst,
#     367                     yearfirst=yearfirst,
# --> 368                     require_iso8601=require_iso8601
#     369                 )
#     370
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# pandas\_libs\tslibs\parsing.pyx in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# ValueError: Given date string not likely a datetime.
